# %%
# Web scraping, pickle imports
import requests
from bs4 import BeautifulSoup
import pickle

# Scrapes transcript data from scrapsfromtheloft.com
def url_to_transcript(url):
    '''Returns transcript data specifically from scrapsfromtheloft.com.'''
    page = requests.get(url).text
    soup = BeautifulSoup(page, 'lxml')
    text = [p.text for p in soup.find_all('p')]
    print(url)
    return text

# URLs of transcripts in scope
urls = [
        'https://scrapsfromtheloft.com/tv-series/the-last-of-us-s01e02-infected-transcript/',
        'https://scrapsfromtheloft.com/tv-series/the-last-of-us-s01e03-long-long-time-transcript/',
        'https://scrapsfromtheloft.com/tv-series/the-last-of-us-s01e04-please-hold-on-to-my-hand-transcript/'
         
        ]

# Comedian names
episodes = ['episode2', 'episode3', 'episode4' ]

# %%
transcripts = [url_to_transcript(u) for u in urls]
# Out:
# https://scrapsfromtheloft.com/tv-series/the-last-of-us-s01e02-infected-transcript/
# https://scrapsfromtheloft.com/tv-series/the-last-of-us-s01e03-long-long-time-transcript/
# https://scrapsfromtheloft.com/tv-series/the-last-of-us-s01e04-please-hold-on-to-my-hand-transcript/

# %%
# !mkdir transcripts

for i, c in enumerate(episodes):
    with open("transcripts/" + c + ".txt", "wb") as file:
        pickle.dump(transcripts[i], file)

# %%
# Load pickled files
data = {}
for i, c in enumerate(episodes):
    with open("transcripts/" + c + ".txt", "rb") as file:
        data[c] = pickle.load(file)

# %%
# Double check to make sure data has been loaded properly
data.keys()
# Out:
# dict_keys(['episode2', 'episode3', 'episode4'])

# %%
next(iter(data.values()))
# Out:
# ['Original air date: January 23, 2023',
#  'On the day of the outbreak, in\xa0Jakarta, Indonesia, a\xa0mycologist\xa0learns of the oncoming pandemic and advises the government to bomb the city to slow the spread. In the present, Ellie explains she is being transported west in hopes of her being used to find a cure. Discovering the path to their meetup is swarmed with infected, they cut through a museum and are attacked by two blind variants of infected, one of whom bites Ellie before Joel and Tess kill them. They arrive at the Old State House to find the Fireflies slaughtered by Infected. Tess reveals she was bitten while Ellie’s bite is healing, proving her immunity. Joel shoots an infected, alerting the others to their location, Tess convinces him to escape with Ellie as she stays behind and blows up the building, killing herself and the horde.',
#  '* * *',
#  '(sirens wailing)',
#  'JAKARTA, INDONESIA\nSEPTEMBER 24TH, 2003',
#  '(cars honking)',
#  '(indistinct chatter)',
#  '(chatter stops)',
#  '(inaudible)',
#  '(ambient street noise)',
#  '(speaking Indonesian) I apologize about your lunch.',
#  '(speaking Indonesian) No need. I was just finishing. Excuse me sir. Have I committed a crime?',
#  'No, of course not.',
#  'Do you have the right person?',
#  'You are Ibu Ratna, Professor of Mycology, University of Indonesia. We have the right person.',
#  'KEMENTERIAN KESEHATAN\nREPUBLIK INDONESIA',
#  '(indistinct chatter)',
#  '(tense music playing)',
#  '(door beeps)',
#  '(speaking Indonesian) Ibu Ratna, would you examine the prepared specimen?',
#  'You may notice–',
#  'She will draw her own conclusions.',
#  '(microscope clicks)',
#  'This is ophiocordyceps. Why did you use chlorazol to prepare the slide?',
#  'Because that is the preparation used for samples taken from a human.',
#  'Cordyceps cannot survive in humans.',
#  '♪ ♪',
#  '(door hisses)',
#  '♪',
#  'If you feel sick please exit quickly.',
#  '♪ ♪',
#  'The bottom of her left leg.',
#  '(Ibu Ratne speaking Indonesian) Is this bite from a human?',
#  '♪ ♪',
#  '(gasps)',
#  '(door opens)',
#  '(door closes)',
#  '(speaking Indonesian) When did this happen?',
#  'Approximately 30 hours ago.',
#  'Where?',
#  'A flour and grain factory on the west side of the city.',
#  'A perfect substrate. And then?',
#  'A normal woman, then suddenly violent. Attacked four coworkers, bit three of them. They locked her in a bathroom, the police came, she tried to attack them, and they shot her.',
#  'What happened to the people she bit?',
#  'They were taken for observation. A few hours later… it became necessary according to procedure to execute them.',
#  'Who bit her?',
#  'We don’t know.',
#  'So they’re still out there. Are any other workers missing?',
#  'Fourteen.',
#  '(heavy breathing)',
#  'Ibu Ratna, brought you here to help us keep this from spreading. We need a vaccine or a medicine.',
#  '♪ ♪',
#  '(speaking Indonesian) I have spent my life studying these things. So please listen carefully. There is no medicine. There is no vaccine.',
#  '♪ ♪',
#  'So what do we do?',
#  'Bomb. Start bombing. Bomb this city… and everyone in it.',
#  '(crying)',
#  'Excuse me, if someone could please drive me home? I would like to be with my family.',
#  '(pensive theme music plays)',
#  '♪ ♪',
#  '(creaking)',
#  '(creaking continues)',
#  '(loud creak)',
#  'Morning.',
#  'Do I look like I’m infected?',
#  'Show us your arm.',
#  'Yeah, it’s not getting any worse, is it? If we’re out in the open city, why aren’t we getting swarmed?',
#  'Joel: Don’t worry about that.',
#  'Well, I’m gonna.',
#  'What was Marlene doing with an infected kid?',
#  'I’m not infected. She found me after I was bitten.',
#  'And she didn’t shoot you.',
#  'Ellie: Clearly not.',
#  'She locked me up and had her guys test me every day to see if I was getting sick.',
#  'Test you how?',
#  'I have to pee.',
#  'Test you… how?',
#  'They’d make me count to 10 and hold out my hand and then keep it steady. But, you know, I think what really impressed them was the fact that I didn’t turn into a fucking monster.',
#  'Now can I please?',
#  'Fine. Back there. You can find a spot.',
#  'And here. Tear out a few pages.',
#  'There’s not gonna be anything bad in here?',
#  'Just you.',
#  'Oh, funny.',
#  '(Tess sighs)',
#  'Broken.',
#  'Maybe a hairline. It’ll heal fast.',
#  'She made it through the fuckin’ night, Joel.',
#  'It doesn’t matter.',
#  'It’s gonna happen sooner or later.',
#  'All right? We’re still close to the wall.',
#  'We sneak her back into the QZ.',
#  'We find a different way to get the battery.',
#  'This is our best shot.',
#  '(Joel sighs)',
#  'We take her back to the QZ, someone’s gonna notice her arm, they’re gonna scan her… then they’ll kill her.',
#  'Well, better them then us.',
#  'You need to stop talkin’ about this kid like she’s got some kinda life in front of her.',
#  '(footsteps approach)',
#  'Tess: You hungry? You can share some of ours.',
#  'Thanks. Marlene sent me with my own.',
#  'Is that chicken?',
#  'Yeah. Marlene said they get it from smugglers.',
#  'Guess not you guys.',
#  'Hey. Hey!',
#  'Why… why are you so important to Marlene? And don’t lie to me or we’ll take you back.',
#  'You take me back, you don’t get your battery.',
#  '(scoffs) You heard that?',
#  'Then you must’ve heard that he wants to shoot you.',
#  'I’m gonna talk to you like you’re an adult.',
#  'Okay?',
#  'Joel and I aren’t good people. We’re doin’ this for us because, apparently, you’re worth something. But we don’t know what you’re worth if we don’t know what we have.',
#  'So answer my question.',
#  'She told me not to tell anybody, and now I’m telling the first people that I…',
#  'There’s a Firefly base camp somewhere out west… with doctors.',
#  'They’re working on a cure.',
#  'Joel: Mm-hm.',
#  'I’ve heard this before.',
#  'And whatever happened to me…',
#  'Ellie/Joel: …is the key to finding the vaccine.',
#  'That’s what this is?',
#  'We’ve heard this a million times.',
#  'Vaccines, miracle cures. None of it works.',
#  'Ever.',
#  'Fuck you, man. I didn’t ask for this.',
#  'You and me both.',
#  'This isn’t gonna end well, Tess.',
#  'We need to go back.',
#  'Let’s just finish it.',
#  'It doesn’t matter if she is or she isn’t what the Fireflies say.',
#  'If they believe that she is then… we get what we want.',
#  'If she so much as twitches.',
#  '(choking, snarling)',
#  'Don’t.',
#  '(Ellie clears throat)',
#  '(softly): Okay.',
#  'Okay?',
#  'Okay.',
#  'Can I have a gun?',
#  'Absolutely not.',
#  'No.',
#  'Okay, Jesus. Fine. I’ll have to throw a fuckin’ sandwich at them.',
#  '(birds chirping)',
#  'Joel: It’s clear.',
#  '(light music playing)',
#  'Whoa.',
#  'Yeah, looks different in the daylight, huh?',
#  '(birds chirping)',
#  '♪ ♪',
#  'We should get movin’.',
#  'It’s like a fucked-up moon.',
#  'Is this where they bombed?',
#  'Tess: Yeah.',
#  'They hit most of the big cities like this.',
#  'They had to slow the spread somehow.',
#  'Worked here, but it… didn’t in most places.',
#  '(tense music playing)',
#  'So, the State House is across there.',
#  'It’s about a 10-minute walk if you could go straight.',
#  'So?',
#  'Long way or short way?',
#  'I mean, it’s the long way or the “we’re fuckin’ dead” way.',
#  'Well, I vote long way just based on that limited information.',
#  'We have to check it from the hotel first.',
#  'Tess: Okay.',
#  '♪ ♪',
#  'Where the fuck are they already?',
#  'You’ll know it when they’re close.',
#  'I didn’t know last time.',
#  'Tess: How did you get bit?',
#  'Ellie: You know the old mall in the QZ?',
#  'Tess: The one that’s sealed off and boarded up, and no one’s supposed to go in… ever?',
#  'That one?',
#  'Whatever. I snuck in.',
#  'Wanted to see what it was like.',
#  'Didn’t think there was gonna be anything in there, and then one just came at me outta nowhere.',
#  'Thought I got away, but.',
#  'So it was just you in there, alone?',
#  'Yeah.',
#  'How old are you?',
#  'Fourteen.',
#  'Wow.',
#  'Well, I mean, you got some balls on you, sister.',
#  'Thanks.',
#  '(cars creaking)',
#  'Nobody’s gonna be comin’ after you, right?',
#  'Like, Mom, Dad… boyfriend?',
#  'I’m an orphan, and, uh, no.',
#  '(birds cawing)',
#  'Everyone said the open city was crazy.',
#  'Like, swarms of Infected running around everywhere.',
#  'Not exactly like that.',
#  'You know, people like to tell stories.',
#  'So, there aren’t Super-Infected that explode fungus spores on you?',
#  'Shit, I hope not.',
#  'Or ones with split-open heads that see in the dark like bats?',
#  '(loud, distant yell)',
#  '♪ ♪',
#  'What was that?',
#  'Let’s keep movin’.',
#  '(quacking)',
#  '(piano notes playing)',
#  '(door creaking)',
#  'You’ve gotta be kidding me!',
#  'Ya ever stay in a place like this?',
#  'Uh, no, a little out of our league.',
#  'How do you even know what this is?',
#  'Have you heard of books?',
#  'Wait, are we going in there?',
#  'Yeah, we gotta get to the stairwell on the other side.',
#  'Well, I, I don’t know how to swim.',
#  'Seriously?',
#  'Do you think we have pools in the QZ?',
#  'Joel: No, smart ass.',
#  'I mean.',
#  'I don’t know how I was supposed to know that.',
#  'This is so gross.',
#  'Oh, check it out!',
#  '(chuckles)',
#  'Ding, ding.',
#  '(bell dings)',
#  'Yes, sir. I would like your finest suite, please.',
#  '(deep voice): Yes, ma’am. Would you like me to take your luggage?',
#  'Yes, ma’am. Right away, ma’am…',
#  'You’re a weird kid.',
#  'You’re a weird kid.',
#  'Ellie: Oh fuck!',
#  '(bangs on piano)',
#  'Oh, my God. (breathing heavily)',
#  'Uh, sorry.',
#  '(piano creaks)',
#  '(pushes piano keys)',
#  'Tess: You okay?',
#  'Ellie: Yep. Fucking fabulous.',
#  '(footsteps approach)',
#  'Fuck… Holy shit.',
#  'Come on, it wasn’t that bad.',
#  'You try climbing ten fuckin’ floors with our knees.',
#  'See how ya feel.',
#  '(water dripping)',
#  'Tess: Well, when the fuck did that happen?',
#  'Maybe that one.',
#  '(doorknob jiggles)',
#  'Joel: No.',
#  'All right, well, I mean, maybe I could climb up there, work my way around, and open it from the inside?',
#  'Uh, no, well, I’m the smallest, so it’d be easier for me to get through.',
#  'Mm-hm, but you die and we get nothing. You stay.',
#  'Can you give me a hand?',
#  '(Ellie scoffs)',
#  '(grunting)',
#  'You good up there?',
#  'Yeah, uh, it’s a bit of a mess, so I’m gonna need a few minutes.',
#  'Nice knife.',
#  'Where’d you learn to do that?',
#  'The circus.',
#  '(sighs)',
#  'Where are you from?',
#  'Texas.',
#  'What about Tess?',
#  'Detroit. It’s in Michigan.',
#  'I go to school. I know where Detroit is.',
#  'So, uh, you two like a…',
#  'Pass.',
#  'How’d you end up in Boston?',
#  'Pass.',
#  'No more questions about me.',
#  'How long do Infected live?',
#  'Oh, I thought you went to school.',
#  'It’s a really shitty one.',
#  'Well, some last about a month or two.',
#  'But there’s others been walkin’ around ’bout 20 years.',
#  'Ever kill one?',
#  'Yeah, I killed lots of ’em.',
#  'Was it hard?',
#  'Like, knowing they were people once?',
#  'Sometimes.',
#  'What about that guy last night?',
#  '(muffled thumping)',
#  'Tess: You can put the gun down, Joel.',
#  '(thumping continues)',
#  'Joel: What now?',
#  '♪ ♪',
#  '(soft shrieking)',
#  'There’s so many.',
#  'The last time we were here, they were still deep inside the buildings.',
#  'Then I guess enough people came through looking for the QZ, they went inside seeking shelter… and that’s how they get more and more of the city bit by bit, year after year.',
#  '(snarling)',
#  'They’re connected.',
#  'More than you know.',
#  'The fungus also grows underground.',
#  'Long fibers like wires, some of them stretching over a mile.',
#  'Now, you step on a patch of cordyceps in one place, and you can wake a dozen Infected from somewhere else.',
#  'Now they know where you are, now they come.',
#  'You’re not immune from being ripped apart.',
#  'You understand?',
#  'It’s important.',
#  'I’m tryin’ to keep you alive.',
#  '(wind blowing)',
#  'So, we’re not goin’ that way.',
#  'No.',
#  'What do we do then?',
#  'Short way?!',
#  'Museum.',
#  '♪ ♪',
#  'Ellie: You’ve gotta be fucking kidding me.',
#  'Well, there’s a way across from the top floor.',
#  'Well, then I guess it’s fine.',
#  'We used to take it all the time.',
#  'Okay.',
#  'Tess: Look, it was fine.',
#  'Ellie: Awesome.',
#  'It’s bone dry.',
#  'It could mean they’re all finally dead in there.',
#  'Oh, man.',
#  'Marlene pack you one of these or just sandwiches?',
#  'Ellie: Yeah.',
#  'Okay, so… more ground rules.',
#  'We’re gonna go slowly.',
#  'If we come up against anything, you get behind us and ya stay there, okay?',
#  'Yes.',
#  'I have a spare hand.',
#  'Congratulations.',
#  '♪ ♪',
#  '(eerie music playing)',
#  'Yeah… cooked.',
#  'Oh, finally, some fuckin’ luck.',
#  'Joel: I guess we should’ve gone this way in the first place.',
#  'Oh shit!',
#  'What the fuck did that?',
#  '(softly): Maybe… maybe he was attacked outside, and crawled through the doors.',
#  'The door was open. Could’ve been him.',
#  'I don’t hear anything.',
#  'Who would you hear?',
#  '(whispers): Who would you hear?',
#  'Are you saying an Infected did that?',
#  'Shh.',
#  'Because I’ve been attacked by one and it wasn’t like that.',
#  '(whispers): Okay, from this point forward, we are silent.',
#  'Not quiet. Silent.',
#  'What…',
#  'No. No questions. Just do it.',
#  '♪ ♪',
#  '(stairs creaking)',
#  '(rumbling)',
#  '(loud crash)',
#  '(debris falling)',
#  '♪ ♪',
#  '(loud crunch)',
#  '(rumbling)',
#  '(indistinct noises)',
#  '♪ ♪',
#  '(door creaks)',
#  '(rumbling)',
#  '(debris falling)',
#  '(loud crash)',
#  '(loud screech)',
#  '(Infected clicking)',
#  '(heavy breathing)',
#  '(tense music playing)',
#  '(snarling)',
#  '(snarling, clicking)',
#  '♪ ♪',
#  '(mouths): They can’t see, but they can hear.',
#  '(growling, screeching)',
#  '(heavy breathing)',
#  '♪ ♪',
#  '(snarling)',
#  '(screeches)',
#  '(Joel grunts, shouts): Run!',
#  '(gunshot)',
#  '(snarling)',
#  '♪ ♪',
#  '(screeching)',
#  '(Joel grunting)',
#  'Tess: Ah! (grunts)',
#  'Run, run!',
#  '(heavy breathing)',
#  '(screeching)',
#  '(heavy breathing)',
#  '(grunts)',
#  '(screeches)',
#  '(snarls)',
#  '♪ ♪',
#  '(panting)',
#  '(thud)',
#  '(creaking)',
#  '(clicking)',
#  '(screeching)',
#  '(snarling)',
#  '♪ ♪',
#  '(guttural clicking)',
#  '(snarling)',
#  '(cracks)',
#  '(screeching)',
#  '(Ellie yelling, grunting)',
#  '(gunshots)',
#  '(snarling)',
#  '♪ ♪',
#  '(screeching)',
#  '(Tess yells)',
#  '(snarling)',
#  '♪ ♪',
#  '(all breathing heavily)',
#  'You all right?',
#  'Twisted ankle, but… yeah.',
#  'You all right?',
#  'Well, I didn’t shit my pants, so.',
#  'You fucking kidding me?',
#  '(sighs) I mean, if it was gonna happen to one of us.',
#  'Hey… let’s get the fuck outta here.',
#  '(wind blowing)',
#  '(Tess grunting)',
#  'Joel: Put this around your arm.',
#  'Thanks.',
#  'Over there?',
#  'Yeah, I know. It looks scary.',
#  'That was scary. This is wood.',
#  'Just wait there. Give us a minute.',
#  'There’s probably more ahead.',
#  'So, we’ll deal with it then.',
#  'I got it. I got it.',
#  'What about the kid?',
#  'I mean, maybe the first bite didn’t take, but what about the second?',
#  'How ’bout you just take the good news?',
#  'Can you do that?',
#  'Like to think, for once, maybe we could actually win?',
#  'Just go, go and watch her.',
#  '(melancholy music playing)',
#  'Is it everything you hoped for?',
#  'Jury’s still out.',
#  'But, man, you can’t deny that view.',
#  'C’mon, let’s get there before it’s dark.',
#  '(Tess grunts)',
#  '(pensive music playing)',
#  '(birds cawing)',
#  '(foreboding music playing)',
#  '♪ ♪',
#  'Tess (softly): Where the fuck are they?',
#  '♪ ♪',
#  '(softly): Stay back.',
#  '♪ ♪',
#  '(insects buzzing)',
#  'Tess: Joel?',
#  'What the fuck is going on?',
#  'I don’t know.',
#  'Ellie: They went inside.',
#  'Come on.',
#  'Tess.',
#  'Come on!',
#  'Joel: Tess!',
#  '♪ ♪',
#  'Ellie: Holy shit.',
#  'Oh, Jesus.',
#  'Okay.',
#  'I mean, there’s gotta be a, a fuckin’ radio or somethin’, right?',
#  'Who killed them? FEDRA?',
#  'No.',
#  'One of them got bit.',
#  'The healthy ones fought the sick ones. Everyone lost.',
#  '(banging)',
#  'Tess? What’re you doin’?',
#  'Where did Marlene say that she was taking you?',
#  'Ellie!',
#  'Uh, I don’t know. Just west.',
#  'Just west. Fuck. Okay.',
#  'Well, I mean, one of them’s gotta have a map on them, right?',
#  'Joel, can ya help me?',
#  'No!',
#  'Tess… it’s over.',
#  'We are going home.',
#  'That’s not my fucking home!',
#  'I’m stayin’.',
#  'I mean… our luck had to run out sooner or later.',
#  'Ellie: Fuck.',
#  'She’s infected.',
#  '(Tess scoffs)',
#  'Show me.',
#  'Joel.',
#  '♪ ♪',
#  'Oops, right?',
#  'Take your bandage off.',
#  '(Ellie sighs)',
#  'Look.',
#  'Joel?',
#  'This is real.',
#  'Joel, she’s fucking real.',
#  'I need you to get her to Bill and Frank’s.',
#  'Joel: No.',
#  'They’ll take her off your hands.',
#  'No.',
#  'They’ll handle it from here.',
#  'No, no, no, I can’t. They won’t take her.',
#  'They’re not gonna take her.',
#  'They will. They will ’cause you’ll convince them.',
#  'Yes, you will.',
#  'I, I never ask you for anything, not to feel the way I felt.',
#  'No.',
#  'Not to… Shut the fuck up ’cause I don’t have time.',
#  'This is your chance.',
#  'You get her there… you keep her alive… and you set everything right.',
#  'All the shit we did.',
#  'Please say yes, Joel, please.',
#  '(loud gasp)',
#  'Oh fuck!',
#  '♪ ♪',
#  '(panting)',
#  '(snarling)',
#  '(gasping)',
#  '♪ ♪',
#  '(distant snarling)',
#  'How many?',
#  'All of them.',
#  'Maybe a minute.',
#  '(grunts)',
#  'What are you doing?',
#  'Making sure that they don’t follow you.',
#  '(grunts)',
#  '(grunts)',
#  '♪ ♪',
#  'Joel… save who you can save.',
#  'No!',
#  'We’re not leaving her!',
#  'Get off me, you fucker!',
#  'I’m not going with you!',
#  '(Tess breathing heavily)',
#  '(snarling)',
#  '(door shaking)',
#  '♪ ♪',
#  '(door opens)',
#  '(snarling)',
#  '(snarling)',
#  '(heavy breathing)',
#  '(gasping)',
#  '♪ ♪',
#  '(Tess grunting)',
#  '(fire erupts)',
#  '(explosion)',
#  '(glass shattering)',
#  '(distant screaming)',
#  '(heavy breathing)',
#  '(melancholy music playing)',
#  '(fire crackling)',
#  '♪ ♪',
#  '♪ ♪',
#  '\n',
#  'Your email address will not be published. Required fields are marked *',
#  'Name*',
#  'E-mail*',
#  'Website',
#  ' \n\n',
#  'After Joel and Ellie leave Bill and Frank’s compound, they come across something that is even more deadly than the infected. People. Joel must protect Ellie at all costs, lest he relive what happened to his daughter all those years ago.',
#  'When a stranger approaches his compound, survivalist Bill forges an unlikely connection. Later, Joel and Ellie seek Bill’s guidance.',
#  'Twenty years after a fungal outbreak ravages the planet, survivors Joel and Ellie are tasked with a mission that could change everything.',
#  'A seasoned sheriff investigates a dead body in the woods and calls on an old pal, a medical examiner, to help piece together a series of chilling events.',
#  '© 2021 Scraps from the Loft. All rights reserved.']

# %%
def combine_text(list_of_text):
    '''Takes a list of text and combines them into one large chunk of text.'''
    combined_text = ' '.join(list_of_text)
    return combined_text

# %%
data_combined = {key: [combine_text(value)] for (key, value) in data.items()}

# %%
import pandas as pd
pd.set_option('max_colwidth',150)

data_df = pd.DataFrame.from_dict(data_combined).transpose()
data_df.columns = ['transcript']
data_df = data_df.sort_index()
data_df
# Out:
#                                                                                                                                                      transcript
# episode2  Original air date: January 23, 2023 On the day of the outbreak, in Jakarta, Indonesia, a mycologist learns of the oncoming pandemic and advises th...
# episode3  Original air date: January 30, 2023 In the present, Joel and Ellie heed Tess’s final instructions and hike to meet allies Bill and Frank. On their...
# episode4  Original air date: February 6, 2023 Traveling through Missouri on their way to Wyoming, Joel and Ellie take a shortcut through the ruins of Kansas...

# %%
import re
import string

def clean_text_round1(text):
    '''Make text lowercase, remove text in square brackets, remove punctuation and remove words containing numbers.'''
    text = text.lower()
    text = re.sub('\[.*?\]', '', text)
    text = re.sub('[%s]' % re.escape(string.punctuation), '', text)
    text = re.sub('\w*\d\w*', '', text)
    text = re.sub(r'[0-9]+','',text)  #number 
    text = re.sub("[^A-Za-z0-9 ]",'',text)  #alpha numeric
    years = re.findall("b(19[40][0-9]|20[0-1][0-9]|2020)b",text)   #years extracter
    return text

round1 = lambda x: clean_text_round1(x)

# %%
data_clean = pd.DataFrame(data_df.transcript.apply(round1))
data_clean
# Out:
#                                                                                                                                                      transcript
# episode2  original air date january   on the day of the outbreak injakarta indonesia amycologistlearns of the oncoming pandemic and advises the government t...
# episode3  original air date january   in the present joel and ellie heed tesss final instructions and hike to meet alliesbillandfrank on their journey joel ...
# episode4  original air date february   traveling throughmissourion their way to wyoming joel and ellie take a shortcut through the ruins ofkansas citywhen t...

# %%
def clean_text_round2(text):
    '''Get rid of some additional punctuation and non-sensical text that was missed the first time around.'''
    text = re.sub('[‘’“”…]', '', text)
    text = re.sub('\n', '', text)
    return text

round2 = lambda x: clean_text_round2(x)

# %%
data_clean = pd.DataFrame(data_clean.transcript.apply(round2))
data_clean
# Out:
#                                                                                                                                                      transcript
# episode2  original air date january   on the day of the outbreak injakarta indonesia amycologistlearns of the oncoming pandemic and advises the government t...
# episode3  original air date january   in the present joel and ellie heed tesss final instructions and hike to meet alliesbillandfrank on their journey joel ...
# episode4  original air date february   traveling throughmissourion their way to wyoming joel and ellie take a shortcut through the ruins ofkansas citywhen t...

# %%
data_df
# Out:
#                                                                                                                                                      transcript
# episode2  Original air date: January 23, 2023 On the day of the outbreak, in Jakarta, Indonesia, a mycologist learns of the oncoming pandemic and advises th...
# episode3  Original air date: January 30, 2023 In the present, Joel and Ellie heed Tess’s final instructions and hike to meet allies Bill and Frank. On their...
# episode4  Original air date: February 6, 2023 Traveling through Missouri on their way to Wyoming, Joel and Ellie take a shortcut through the ruins of Kansas...

# %%
data_df.to_pickle("corpus.pkl")

# %%
from sklearn.feature_extraction.text import CountVectorizer

cv = CountVectorizer(stop_words='english')
data_cv = cv.fit_transform(data_clean.transcript)
data_dtm = pd.DataFrame(data_cv.toarray(), columns=cv.get_feature_names())
data_dtm.index = data_clean.index
data_dtm
# Out:
# /usr/local/lib/python3.8/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)
#           abandoned  abide  absolutely  accelerates  accelerating  according  \
# episode2          0      0           1            0             0          1
# episode3          1      3           0            1             0          0
# episode4          1      0           0            0             1          0
#
#           actually  address  adult  advice  ...  yelps  yep  yes  youd  youll  \
# episode2         1        1      1       0  ...      0    1    6     0      2
# episode3         3        1      0       3  ...      0    2   10     0      5
# episode4         3        1      0       0  ...      1    0    1     1      1
#
#           younger  youre  youve  yuck  zeroing
# episode2        0      6      2     0        0
# episode3        0     10      1     1        1
# episode4        2     10      0     0        0
#
# [3 rows x 1603 columns]

# %%
data_dtm.to_pickle("dtm.pkl")

# %%
# Let's also pickle the cleaned data (before we put it in document-term matrix format) and the CountVectorizer object
data_clean.to_pickle('data_clean.pkl')
pickle.dump(cv, open("cv.pkl", "wb"))
